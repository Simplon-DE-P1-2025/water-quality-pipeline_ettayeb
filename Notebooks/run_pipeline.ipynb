# %%
try:

    dbutils.notebook.run("/Workspace/Brief_eau_69/ingestion bronze", 0)

    dbutils.notebook.run("/Workspace/Brief_eau_69/Silver_transfo", 0)

    dbutils.notebook.run("/Workspace/Brief_eau_69/Gold_agrega", 0)

    print("✅ Pipeline terminé")

except Exception as e:

    print("❌ Erreur pipeline :")
    print(str(e))
